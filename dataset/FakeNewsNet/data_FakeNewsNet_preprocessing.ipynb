# %%
# %pip install pandas
import pandas as pd

# %pip install tqdm
from tqdm import tqdm

import os
import json
# Out:
# Requirement already satisfied: pandas in ./env_dateset/lib/python3.11/site-packages (1.5.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./env_dateset/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./env_dateset/lib/python3.11/site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in ./env_dateset/lib/python3.11/site-packages (from pandas) (1.24.1)
# Requirement already satisfied: six>=1.5 in ./env_dateset/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in ./env_dateset/lib/python3.11/site-packages (4.64.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
base_path = 'FakeNewsNet/'
folders = ['gossipcop_fake', 'gossipcop_real', 'politifact_fake', 'politifact_real']

# %%
path = base_path + folders[0] + '.csv'
dataset_raw_df = pd.read_csv(path)

dataset_df = dataset_raw_df
dataset_df = dataset_df[dataset_df['tweet_ids'].notna()]

# https://stackoverflow.com/a/57122617
dataset_df = dataset_df.assign(tweet_ids=dataset_df['tweet_ids'].str.split('\t')).explode('tweet_ids').reset_index()

dataset_df.head()
# Out:
#    index                    id  \
# 0      0  gossipcop-2493749932
# 1      0  gossipcop-2493749932
# 2      0  gossipcop-2493749932
# 3      0  gossipcop-2493749932
# 4      0  gossipcop-2493749932
#
#                                             news_url  \
# 0  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 1  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 2  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 3  www.dailymail.co.uk/tvshowbiz/article-5874213/...
# 4  www.dailymail.co.uk/tvshowbiz/article-5874213/...
#
#                                                title           tweet_ids
# 0  Did Miley Cyrus and Liam Hemsworth secretly ge...  284329075902926848
# 1  Did Miley Cyrus and Liam Hemsworth secretly ge...  284332744559968256
# 2  Did Miley Cyrus and Liam Hemsworth secretly ge...  284335412590297089
# 3  Did Miley Cyrus and Liam Hemsworth secretly ge...  284359918792880128
# 4  Did Miley Cyrus and Liam Hemsworth secretly ge...  284385385151332353

# %% [markdown]
# ## Tweets

# %%
def tweet_data_transform(tweet):

# %%
for file in folders:
    filename = file + ".json"

    with open(base_path + filename, 'r') as f:
        data = json.load(f)
# Out:
#        lang                   id  \
# 0        en  1029123395739414528
# 1        en   998353516434518016
# 2        en  1051158211208736768
# 3        en  1011368336804937728
# 4        en   954584822474838016
# ...     ...                  ...
# 371657   en  1056566490827112448
# 371658   en  1008495585580765184
# 371659   en   672238539845726208
# 371660   en  1019232825935974400
# 371661   en   493844440927440896
#
#                                                  entities  \
# 0       {'annotations': [{'start': 12, 'end': 24, 'pro...
# 1       {'hashtags': [{'start': 110, 'end': 116, 'tag'...
# 2       {'annotations': [{'start': 82, 'end': 87, 'pro...
# 3       {'annotations': [{'start': 10, 'end': 19, 'pro...
# 4       {'annotations': [{'start': 0, 'end': 11, 'prob...
# ...                                                   ...
# 371657  {'mentions': [{'start': 0, 'end': 9, 'username...
# 371658  {'urls': [{'start': 75, 'end': 98, 'url': 'htt...
# 371659  {'annotations': [{'start': 15, 'end': 28, 'pro...
# 371660  {'mentions': [{'start': 26, 'end': 42, 'userna...
# 371661  {'annotations': [{'start': 20, 'end': 29, 'pro...
#
#                                            public_metrics  \
# 0       {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 1       {'retweet_count': 1, 'reply_count': 1, 'like_c...
# 2       {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 3       {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 4       {'retweet_count': 0, 'reply_count': 0, 'like_c...
# ...                                                   ...
# 371657  {'retweet_count': 0, 'reply_count': 1, 'like_c...
# 371658  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 371659  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 371660  {'retweet_count': 0, 'reply_count': 0, 'like_c...
# 371661  {'retweet_count': 0, 'reply_count': 0, 'like_c...
#
#                                       context_annotations  possibly_sensitive  \
# 0       [{'domain': {'id': '10', 'name': 'Person', 'de...               False
# 1       [{'domain': {'id': '3', 'name': 'TV Shows', 'd...               False
# 2       [{'domain': {'id': '3', 'name': 'TV Shows', 'd...               False
# 3       [{'domain': {'id': '10', 'name': 'Person', 'de...               False
# 4       [{'domain': {'id': '10', 'name': 'Person', 'de...                True
# ...                                                   ...                 ...
# 371657  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...               False
# 371658  [{'domain': {'id': '29', 'name': 'Events [Enti...               False
# 371659                                               None               False
# 371660  [{'domain': {'id': '3', 'name': 'TV Shows', 'd...               False
# 371661                                               None               False
#
#                 created_at            author_id  \
# 0      2018-08-13 21:51:52  1012203358512443392
# 1      2018-05-21 00:03:21   829904857305927680
# 2      2018-10-13 17:10:21             31259532
# 3      2018-06-25 21:59:36            194346085
# 4      2018-01-20 05:22:11             31469390
# ...                    ...                  ...
# 371657 2018-10-28 15:20:56           2449819634
# 371658 2018-06-17 23:44:19           3087796935
# 371659 2015-12-03 02:18:52            858651145
# 371660 2018-07-17 14:50:16            306887800
# 371661 2014-07-28 19:44:24            949598167
#
#                                                      text  \
# 0       On Air with Ryan Seacrest is offering you a ch...
# 1       ‘American Idol’ final: How to vote for the sea...
# 2       @ScottDisick @KrisJenner @khloekardashian — LA...
# 3       @foquinha Youngblood - 5 Seconds of Summer \nO...
# 4       Kylie Jenner ‘Open’ To Reconciliation With Tyg...
# ...                                                   ...
# 371657  @pucknut9 Did not.  It was an absolute gong sh...
# 371658  Brad Pitt Spends Father’s Day in London with H...
# 371659  'ungratefultch Kim Kardashian At War With Kyli...
# 371660  Ugh revenge body I need u @khloekardashian mak...
# 371661  Lol RT @MissMandii: brunokaman it's not nicki ...
#
#             conversation_id edit_history_tweet_ids reply_settings  \
# 0       1029123395739414528  [1029123395739414529]       everyone
# 1        998353516434518016   [998353516434518016]       everyone
# 2       1051158211208736768  [1051158211208736768]       everyone
# 3       1011289623119716352  [1011368336804937728]       everyone
# 4        954584822474838016   [954584822474838016]       everyone
# ...                     ...                    ...            ...
# 371657  1056563640579457024  [1056566490827112448]       everyone
# 371658  1008495585580765184  [1008495585580765184]       everyone
# 371659   672238539845726208   [672238539845726209]       everyone
# 371660  1019232825935974400  [1019232825935974406]       everyone
# 371661   493844440927440896   [493844440927440896]       everyone
#
#         in_reply_to_user_id  \
# 0                       NaN
# 1                       NaN
# 2               101928415.0
# 3                18141369.0
# 4                       NaN
# ...                     ...
# 371657           34105383.0
# 371658                  NaN
# 371659                  NaN
# 371660                  NaN
# 371661                  NaN
#
#                                         referenced_tweets   geo withheld
# 0                                                    None  None     None
# 1                                                    None  None     None
# 2       [{'type': 'quoted', 'id': '1050443040668770304'}]  None     None
# 3       [{'type': 'replied_to', 'id': '101128962311971...  None     None
# 4                                                    None  None     None
# ...                                                   ...   ...      ...
# 371657  [{'type': 'replied_to', 'id': '105656591896749...  None     None
# 371658                                               None  None     None
# 371659                                               None  None     None
# 371660                                               None  None     None
# 371661                                               None  None     None
#
# [371662 rows x 16 columns]
