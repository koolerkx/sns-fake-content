# %%
count = {
    "label": "BOW",
    
    "nb_pipeline": {
        "auc": 0.5146794963615265,
        "accuracy": 0.4763505589867876,
        "precision": 0.36110054520096363,
        "recall": 0.6319059241180386,
        "f1": 0.45957721478134583
    },
    "lr_pipeline": {
        "auc": 0.5085862867751083,
        "accuracy": 0.45250566804784614,
        "precision": 0.35241248817407755,
        "recall": 0.6611936986909253,
        "f1": 0.4597701149425287
    },
    "dt_pipeline": {
        "auc": 0.5143027954690793,
        "accuracy": 0.49597373152998203,
        "precision": 0.36295563718564566,
        "recall": 0.5700022187708009,
        "f1": 0.44350453172205434
    },
    "rf_pipeline": {
        "auc": 0.5170750135231456,
        "accuracy": 0.493159252599484,
        "precision": 0.35751370060571097,
        "recall": 0.5500332815620147,
        "f1": 0.4333537278209947
    },
    "svm_pipeline": {
        "auc": 0.5219730357744918,
        "accuracy": 0.4633726839183801,
        "precision": 0.35709955135200677,
        "recall": 0.6534280008875083,
        "f1": 0.4618159008938372
    }
}

# %%
tfidf = {
    "label": "tfidf",
    
    "nb_pipeline": {
        "auc": 0.5146794963615265,
        "accuracy": 0.4763505589867876,
        "precision": 0.36110054520096363,
        "recall": 0.6319059241180386,
        "f1": 0.45957721478134583
    },
    "lr_pipeline": {
        "auc": 0.51573744345536,
        "accuracy": 0.4431240716128528,
        "precision": 0.3564845292955892,
        "recall": 0.7208786332371866,
        "f1": 0.4770574847661699
    },
    "dt_pipeline": {
        "auc": 0.513577824698251,
        "accuracy": 0.486123055273239,
        "precision": 0.36215639178009074,
        "recall": 0.6021743953849568,
        "f1": 0.45229564202983086
    },
    "rf_pipeline": {
        "auc": 0.5208339069532592,
        "accuracy": 0.4787741380658275,
        "precision": 0.36118251928020567,
        "recall": 0.6234745950743288,
        "f1": 0.45739399365182715
    },
    "svm_pipeline": {
        "auc": 0.5186947242430011,
        "accuracy": 0.43116253615823624,
        "precision": 0.3573121714933526,
        "recall": 0.7692478366984691,
        "f1": 0.4879662209711471
    }
}

# %%
fasttext = {
    "label": "fasttext",
    
    "nb_pipeline": {
        "auc": 0.49273013747486744,
        "accuracy": 0.4300680165741537,
        "precision": 0.34846999891103125,
        "recall": 0.7100066563124029,
        "f1": 0.46749452154857557
    },
    "lr_pipeline": {
        "auc": 0.5046489729962416,
        "accuracy": 0.4416386521773122,
        "precision": 0.3521822057668574,
        "recall": 0.6964721544264477,
        "f1": 0.4678092399403874
    },
    "dt_pipeline": {
        "auc": 0.5005112761446141,
        "accuracy": 0.4812758971151591,
        "precision": 0.35283540802213004,
        "recall": 0.5660084313290437,
        "f1": 0.4346937036721479
    },
    "rf_pipeline": {
        "auc": 0.4918995447502287,
        "accuracy": 0.4521929481666797,
        "precision": 0.34774665042630937,
        "recall": 0.633459063678722,
        "f1": 0.44900526853817724
    },
    "svm_pipeline": {
        "auc": 0.4968390819067116,
        "accuracy": 0.4188882808224533,
        "precision": 0.3502865329512894,
        "recall": 0.7594852451741735,
        "f1": 0.4794453393094754
    }
}

# %%
word2vec = {
    "label": "word2vec",
    "nb_pipeline": {
        "auc": 0.491478329165951,
        "accuracy": 0.4322570557423188,
        "precision": 0.3479412738712882,
        "recall": 0.6993565564677169,
        "f1": 0.46469113961374026
    },
    "lr_pipeline": {
        "auc": 0.5046671725949773,
        "accuracy": 0.44030959268235476,
        "precision": 0.35174418604651164,
        "recall": 0.6980252939871311,
        "f1": 0.46777191286893166
    },
    "dt_pipeline": {
        "auc": 0.4939704019617748,
        "accuracy": 0.4838558361347823,
        "precision": 0.34719183078045224,
        "recall": 0.5280674506323497,
        "f1": 0.41894032740714665
    },
    "rf_pipeline": {
        "auc": 0.4887977787008074,
        "accuracy": 0.45305292783988743,
        "precision": 0.34434021263289555,
        "recall": 0.6108276015087641,
        "f1": 0.440409534474484
    },
    "svm_pipeline": {
        "auc": 0.5040729202077096,
        "accuracy": 0.42209365960440937,
        "precision": 0.3539240506329114,
        "recall": 0.7754603949412026,
        "f1": 0.48602419691280757
    }
}

# %%
import polars as pl

data = pl.DataFrame([count, tfidf, fasttext, word2vec]).select([
    pl.all().exclude('nb_pipeline'),
    pl.col('nb_pipeline').struct.field('auc').alias('NB AUC'),
    pl.col('nb_pipeline').struct.field('accuracy').alias('NB accuracy'),
    pl.col('nb_pipeline').struct.field('precision').alias('NB precision'),
    pl.col('nb_pipeline').struct.field('recall').alias('NB recall'),
    pl.col('nb_pipeline').struct.field('f1').alias('NB f1'),
]).select([
    pl.all().exclude('lr_pipeline'),
    pl.col('lr_pipeline').struct.field('auc').alias('LR AUC'),
    pl.col('lr_pipeline').struct.field('accuracy').alias('LR accuracy'),
    pl.col('lr_pipeline').struct.field('precision').alias('LR precision'),
    pl.col('lr_pipeline').struct.field('recall').alias('LR recall'),
    pl.col('lr_pipeline').struct.field('f1').alias('LR f1'),
]).select([
    pl.all().exclude('dt_pipeline'),
    pl.col('dt_pipeline').struct.field('auc').alias('DT AUC'),
    pl.col('dt_pipeline').struct.field('accuracy').alias('DT accuracy'),
    pl.col('dt_pipeline').struct.field('precision').alias('DT precision'),
    pl.col('dt_pipeline').struct.field('recall').alias('DT recall'),
    pl.col('dt_pipeline').struct.field('f1').alias('DT f1'),
]).select([
    pl.all().exclude('rf_pipeline'),
    pl.col('rf_pipeline').struct.field('auc').alias('RF AUC'),
    pl.col('rf_pipeline').struct.field('accuracy').alias('RF accuracy'),
    pl.col('rf_pipeline').struct.field('precision').alias('RF precision'),
    pl.col('rf_pipeline').struct.field('recall').alias('RF recall'),
    pl.col('rf_pipeline').struct.field('f1').alias('RF f1'),
]).select([
    pl.all().exclude('svm_pipeline'),
    pl.col('svm_pipeline').struct.field('auc').alias('SVM AUC'),
    pl.col('svm_pipeline').struct.field('accuracy').alias('SVM accuracy'),
    pl.col('svm_pipeline').struct.field('precision').alias('SVM precision'),
    pl.col('svm_pipeline').struct.field('recall').alias('SVM recall'),
    pl.col('svm_pipeline').struct.field('f1').alias('SVM f1'),
])\
#     .select([
#     pl.all().exclude('RNN'),
#     pl.col('RNN').struct.field('auc').alias('RNN AUC'),
#     pl.col('RNN').struct.field('accuracy').alias('RNN accuracy'),
#     pl.col('RNN').struct.field('precision').alias('RNN precision'),
#     pl.col('RNN').struct.field('recall').alias('RNN recall'),
#     pl.col('RNN').struct.field('f1').alias('RNN f1'),
# ])

# %%
data
# Out:
# shape: (4, 26)
# ┌──────────┬──────────┬───────────┬────────────┬───┬────────────┬────────────┬──────────┬──────────┐
# │ label    ┆ NB AUC   ┆ NB        ┆ NB         ┆ … ┆ SVM        ┆ SVM        ┆ SVM      ┆ SVM f1   │
# │ ---      ┆ ---      ┆ accuracy  ┆ precision  ┆   ┆ accuracy   ┆ precision  ┆ recall   ┆ ---      │
# │ str      ┆ f64      ┆ ---       ┆ ---        ┆   ┆ ---        ┆ ---        ┆ ---      ┆ f64      │
# │          ┆          ┆ f64       ┆ f64        ┆   ┆ f64        ┆ f64        ┆ f64      ┆          │
# ╞══════════╪══════════╪═══════════╪════════════╪═══╪════════════╪════════════╪══════════╪══════════╡
# │ BOW      ┆ 0.514679 ┆ 0.476351  ┆ 0.361101   ┆ … ┆ 0.463373   ┆ 0.3571     ┆ 0.653428 ┆ 0.461816 │
# │ tfidf    ┆ 0.514679 ┆ 0.476351  ┆ 0.361101   ┆ … ┆ 0.431163   ┆ 0.357312   ┆ 0.769248 ┆ 0.487966 │
# │ fasttext ┆ 0.49273  ┆ 0.430068  ┆ 0.34847    ┆ … ┆ 0.418888   ┆ 0.350287   ┆ 0.759485 ┆ 0.479445 │
# ...

# %%
data.select(['label', 'NB accuracy', 'LR accuracy', 'DT accuracy', 'RF accuracy', 'SVM accuracy'])
# Out:
# shape: (4, 6)
# ┌──────────┬─────────────┬─────────────┬─────────────┬─────────────┬──────────────┐
# │ label    ┆ NB accuracy ┆ LR accuracy ┆ DT accuracy ┆ RF accuracy ┆ SVM accuracy │
# │ ---      ┆ ---         ┆ ---         ┆ ---         ┆ ---         ┆ ---          │
# │ str      ┆ f64         ┆ f64         ┆ f64         ┆ f64         ┆ f64          │
# ╞══════════╪═════════════╪═════════════╪═════════════╪═════════════╪══════════════╡
# │ BOW      ┆ 0.476351    ┆ 0.452506    ┆ 0.495974    ┆ 0.493159    ┆ 0.463373     │
# │ tfidf    ┆ 0.476351    ┆ 0.443124    ┆ 0.486123    ┆ 0.478774    ┆ 0.431163     │
# │ fasttext ┆ 0.430068    ┆ 0.441639    ┆ 0.481276    ┆ 0.452193    ┆ 0.418888     │
# │ word2vec ┆ 0.432257    ┆ 0.44031     ┆ 0.483856    ┆ 0.453053    ┆ 0.422094     │
# └──────────┴─────────────┴─────────────┴─────────────┴─────────────┴──────────────┘

# %%
data.select(['label', 'NB AUC', 'LR AUC', 'DT AUC', 'RF AUC', 'SVM AUC', 'RNN AUC'])
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[111], line 1
# ----> 1 data.select(['label', 'NB AUC', 'LR AUC', 'DT AUC', 'RF AUC', 'SVM AUC', 'RNN AUC'])
#
# File ~/dev/sw/sns-fake-content/analysis/env_analysis/lib/python3.8/site-packages/polars/dataframe/frame.py:6503, in DataFrame.select(self, exprs, *more_exprs, **named_exprs)
#    6395 def select(
#    6396     self,
#    6397     exprs: IntoExpr | Iterable[IntoExpr] | None = None,
#    6398     *more_exprs: IntoExpr,
#    6399     **named_exprs: IntoExpr,
#    6400 ) -> Self:
#    6401     """
#    6402     Select columns from this DataFrame.
#    6403
#    (...)
#    6500
#    6501     """
#    6502     return self._from_pydf(
# -> 6503         self.lazy()
#    6504         .select(exprs, *more_exprs, **named_exprs)
#    6505         .collect(no_optimization=True)
#    6506         ._df
#    6507     )
#
# ...

# %%
data.select(['label', 'NB f1', 'LR f1', 'DT f1', 'RF f1', 'SVM f1', 'RNN f1'])
# Out:
# shape: (4, 7)
# ┌──────────┬──────────┬──────────┬──────────┬──────────┬──────────┬──────────┐
# │ label    ┆ NB f1    ┆ LR f1    ┆ DT f1    ┆ RF f1    ┆ SVM f1   ┆ RNN f1   │
# │ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str      ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# ╞══════════╪══════════╪══════════╪══════════╪══════════╪══════════╪══════════╡
# │ BOW      ┆ 0.837994 ┆ 0.864609 ┆ 0.804298 ┆ 0.860335 ┆ 0.870188 ┆ null     │
# │ TF-IDF   ┆ 0.837994 ┆ 0.867012 ┆ 0.79646  ┆ 0.852624 ┆ 0.887961 ┆ null     │
# │ FastText ┆ 0.625999 ┆ 0.588663 ┆ 0.628067 ┆ 0.690574 ┆ 0.660283 ┆ 0.886053 │
# │ Word2Vec ┆ 0.614016 ┆ 0.588577 ┆ 0.611402 ┆ 0.689266 ┆ 0.644141 ┆ 0.882454 │
# └──────────┴──────────┴──────────┴──────────┴──────────┴──────────┴──────────┘

# %%
import pandas as pd

# %%
pd.DataFrame(fasttext)
# Out:
#               label  nb_pipeline  lr_pipeline  dt_pipeline  rf_pipeline  \
# auc        FastText     0.578161     0.591565     0.620498     0.764190
# accuracy   FastText     0.555500     0.575500     0.621000     0.680750
# precision  FastText     0.549889     0.584135     0.631164     0.685426
# recall     FastText     0.726562     0.593262     0.625000     0.695801
# f1         FastText     0.625999     0.588663     0.628067     0.690574
#
#            svm_pipeline       RNN
# auc            0.642147  0.950726
# accuracy       0.609750  0.884219
# precision      0.595603  0.874567
# recall         0.740723  0.897843
# f1             0.660283  0.886053

# %%
pd.DataFrame(count)
# Out:
#           label  nb_pipeline  lr_pipeline  dt_pipeline  rf_pipeline  \
# auc         BOW     0.514679     0.508586     0.514303     0.517075
# accuracy    BOW     0.476351     0.452506     0.495974     0.493159
# precision   BOW     0.361101     0.352412     0.362956     0.357514
# recall      BOW     0.631906     0.661194     0.570002     0.550033
# f1          BOW     0.459577     0.459770     0.443505     0.433354
#
#            svm_pipeline
# auc            0.521973
# accuracy       0.463373
# precision      0.357100
# recall         0.653428
# f1             0.461816
